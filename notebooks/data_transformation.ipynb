# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np

# %%
# Load dataset
df = pd.read_csv('/Users/jeevanapathipati/Documents/TruckDelay/datasets/final_merge_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10475 entries, 0 to 10474
# Data columns (total 49 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   truck_id                        10475 non-null  int64
#  1   route_id                        10475 non-null  object
#  2   departure_date                  10475 non-null  object
#  3   estimated_arrival               10475 non-null  object
#  4   delay                           10475 non-null  int64
#  5   route_avg_temp                  10475 non-null  float64
#  6   route_avg_wind_speed            10475 non-null  float64
#  7   route_avg_precip                10475 non-null  float64
#  8   route_avg_humidity              10475 non-null  float64
#  9   route_avg_visibility            10475 non-null  float64
#  10  route_avg_pressure              10475 non-null  float64
#  11  route_description               10475 non-null  object
# ...

# %%
df.head()
# Out:
#    truck_id    route_id       departure_date    estimated_arrival  delay  \
# 0  14223048  R-4f2e8b29  2019-02-03 07:00:00  2019-02-03 12:45:00      0
# 1  22748353  R-73f77646  2019-01-25 07:00:00  2019-01-25 23:32:24      0
# 2  27677000  R-7430e046  2019-01-31 07:00:00  2019-02-01 01:41:24      1
# 3  33250272  R-d9f80fa7  2019-01-31 07:00:00  2019-01-31 11:48:36      0
# 4  22695998  R-41fb82a2  2019-02-06 07:00:00  2019-02-06 13:59:24      0
#
#    route_avg_temp  route_avg_wind_speed  route_avg_precip  route_avg_humidity  \
# 0       71.000000              9.333333               0.0                65.0
# 1       40.500000              9.500000               0.0                52.0
# 2       37.500000             19.500000               0.0                71.5
# 3       26.500000              7.000000               0.0                80.5
# 4       52.666667             11.333333               0.0                72.0
#
# ...

# %%
df.shape
# Out:
# (10475, 49)

# %%
# Identify categorical columns and numeric columns
categorical_cols = [ 'route_description', 'description_origin', 'description_destination', 'fuel_type', 
    'gender', 'driving_style']
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# %%
df.isnull().sum()
# Out:
# truck_id                          0
# route_id                          0
# departure_date                    0
# estimated_arrival                 0
# delay                             0
# route_avg_temp                    0
# route_avg_wind_speed              0
# route_avg_precip                  0
# route_avg_humidity                0
# route_avg_visibility              0
# route_avg_pressure                0
# route_description                 0
# estimated_arrival_nearest_hour    0
# departure_date_nearest_hour       0
# origin_id                         0
# destination_id                    0
# distance                          0
# average_hours                     0
# temp_origin                       0
# wind_speed_origin                 0
# description_origin                0
# precip_origin                     0
# humidity_origin                   0
# visibility_origin                 0
# pressure_origin                   0
# temp_destination                  0
# ...

# %%
df.route_description.unique()
# Out:
# array(['Clear', 'Light snow', 'Overcast', 'Light rain', 'Sunny',
#        'Patchy light drizzle', 'Mist', 'Light rain shower',
#        'Patchy light snow', 'Partly cloudy', 'Patchy heavy snow',
#        'Cloudy', 'Moderate or heavy rain shower', 'Patchy rain possible',
#        'Light drizzle', 'Moderate or heavy snow with thunder',
#        'Heavy rain', 'Fog', 'Torrential rain shower', 'Heavy snow',
#        'Thundery outbreaks possible', 'Moderate rain',
#        'Patchy light rain with thunder', 'Moderate snow',
#        'Patchy light rain', 'Blizzard', 'Moderate or heavy snow showers',
#        'Moderate rain at times', 'Freezing fog',
#        'Moderate or heavy rain with thunder', 'Patchy moderate snow',
#        'Patchy light snow with thunder', 'Light sleet',
#        'Heavy rain at times', 'Blowing snow', 'Light freezing rain',
#        'Patchy snow possible', 'Light sleet showers',
#        'Moderate or heavy freezing rain', 'Moderate or heavy sleet',
# ...

# %%
df.route_description.value_counts()
# Out:
# route_description
# Clear                                  3478
# Sunny                                  1841
# Partly cloudy                          1125
# Patchy rain possible                    527
# Cloudy                                  487
# Overcast                                459
# Light rain shower                       414
# Moderate or heavy rain shower           383
# Mist                                    260
# Light drizzle                           187
# Fog                                     154
# Light rain                              145
# Heavy snow                              140
# Moderate rain                           117
# Light snow                               77
# Moderate snow                            67
# Heavy rain                               61
# Blizzard                                 61
# Patchy light rain with thunder           54
# Torrential rain shower                   53
# Patchy light drizzle                     43
# ...

# %%
print(df.description_origin.unique())
df.description_origin.value_counts()
# Out:
# ['Mist' 'Sunny' 'Partly cloudy' 'Moderate rain' 'Patchy moderate snow'
#  'Moderate snow' 'Heavy snow' 'Cloudy' 'Overcast'
#  'Moderate or heavy freezing rain' 'Heavy freezing drizzle'
#  'Patchy light snow' 'Light snow' 'Blizzard' 'Patchy rain possible'
#  'Heavy rain' 'Fog' 'Moderate rain at times' 'Light rain shower'
#  'Patchy freezing drizzle possible' 'Light freezing rain' 'Blowing snow'
#  'Light rain' 'Light drizzle' 'Patchy light drizzle' 'Patchy heavy snow'
#  'Moderate or heavy rain shower' 'Moderate or heavy rain with thunder'
#  'Freezing fog' 'Moderate or heavy snow showers']
# description_origin
# Sunny                                  3121
# Partly cloudy                          1720
# Overcast                               1700
# Cloudy                                  748
# Heavy snow                              566
# Moderate snow                           321
# Mist                                    318
# Heavy rain                              226
# ...

# %%
print(df.description_destination.unique())
df.description_destination.value_counts()
# Out:
# ['Partly cloudy' 'Clear' 'Heavy snow' 'Overcast' 'Sunny' 'Cloudy'
#  'Moderate snow' 'Moderate rain' 'Blizzard' 'Patchy light drizzle'
#  'Light rain' 'Heavy rain' 'Patchy light rain' 'Patchy light snow'
#  'Light snow' 'Mist' 'Light drizzle' 'Light freezing rain'
#  'Patchy rain possible' 'Light rain shower'
#  'Moderate or heavy snow showers' 'Ice pellets'
#  'Moderate or heavy rain with thunder' 'Fog' 'Blowing snow' 'Light sleet'
#  'Moderate rain at times' 'Patchy moderate snow' 'Light snow showers'
#  'Patchy snow possible' 'Patchy heavy snow'
#  'Moderate or heavy freezing rain' 'Moderate or heavy sleet'
#  'Heavy freezing drizzle' 'Moderate or heavy rain shower'
#  'Patchy light rain with thunder' 'Freezing fog'
#  'Thundery outbreaks possible' 'Moderate or heavy showers of ice pellets'
#  'Patchy sleet possible' 'Torrential rain shower']
# description_destination
# Clear                                       1763
# Sunny                                       1678
# ...

# %%
print(df.fuel_type.unique())
df.fuel_type.value_counts()
# Out:
# ['diesel' 'gas']
# fuel_type
# diesel    5857
# gas       4618
# Name: count, dtype: int64

# %%
print(df.driving_style.unique())
df.driving_style.value_counts()
# Out:
# ['proactive' 'conservative']
# driving_style
# proactive       5639
# conservative    4836
# Name: count, dtype: int64

# %%
# Initialize encoders and scalers
label_encoder = LabelEncoder()
scaler = StandardScaler()

# %%
# Encoding categorical columns
for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
df['route_description'].value_counts()
# Out:
# route_description
# 2     3478
# 40    1841
# 29    1125
# 37     527
# 3      487
# 28     459
# 13     414
# 19     383
# 17     260
# 10     187
# 4      154
# 12     145
# 9      140
# 25     117
# 16      77
# 27      67
# 7       61
# 0       61
# 33      54
# 42      53
# 31      43
# 32      42
# 23      40
# 41      35
# 26      33
# 34      33
# 6       28
# 30      27
# 36      22
# 1       17
# 14      16
# 20      12
# 39       8
# 24       6
# 15       6
# 38       4
# 11       3
# 18       3
# 35       2
# 8        2
# 21       1
# 22       1
# 5        1
# Name: count, dtype: int64

# %%
# Scaling numeric columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df
# Out:
#        truck_id    route_id       departure_date    estimated_arrival  \
# 0     -0.846564  R-4f2e8b29  2019-02-03 07:00:00  2019-02-03 12:45:00
# 1     -0.460797  R-73f77646  2019-01-25 07:00:00  2019-01-25 23:32:24
# 2     -0.237778  R-7430e046  2019-01-31 07:00:00  2019-02-01 01:41:24
# 3      0.014410  R-d9f80fa7  2019-01-31 07:00:00  2019-01-31 11:48:36
# 4     -0.463166  R-41fb82a2  2019-02-06 07:00:00  2019-02-06 13:59:24
# ...         ...         ...                  ...                  ...
# 10470 -0.751430  R-eaef7c11  2019-02-03 07:00:00  2019-02-03 18:55:12
# 10471 -0.635138  R-38d1e82d  2019-02-12 07:00:00  2019-02-12 20:13:48
# 10472 -0.842316  R-8fdff50b  2019-01-10 07:00:00  2019-01-10 21:45:36
# 10473 -0.637185  R-03ec1b30  2019-01-10 07:00:00  2019-01-11 06:07:12
# 10474 -0.839909  R-d372b2ff  2019-02-12 07:00:00  2019-02-12 16:33:36
#
#           delay  route_avg_temp  route_avg_wind_speed  route_avg_precip  \
# ...
